# %%
# !pip install easyocr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch in c:\users\thanu\appdata\roaming\python\python310\site-packages (from easyocr) (2.4.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\thanu\appdata\roaming\python\python310\site-packages (from easyocr) (0.19.1)
# Collecting opencv-python-headless (from easyocr)
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scipy in c:\users\thanu\appdata\roaming\python\python310\site-packages (from easyocr) (1.14.0)
# Requirement already satisfied: numpy in c:\users\thanu\appdata\roaming\python\python310\site-packages (from easyocr) (1.24.2)
# Requirement already satisfied: Pillow in c:\users\thanu\appdata\roaming\python\python310\site-packages (from easyocr) (10.4.0)
# Collecting scikit-image (from easyocr)
#   Downloading scikit_image-0.25.2-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.6.6-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: PyYAML in c:\users\thanu\appdata\roaming\python\python310\site-packages (from easyocr) (6.0)
# Collecting Shapely (from easyocr)
#   Downloading shapely-2.0.7-cp310-cp310-win_amd64.whl.metadata (7.1 kB)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.3.0.post6-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Collecting ninja (from easyocr)
#   Downloading ninja-1.11.1.3-py3-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: filelock in c:\users\thanu\appdata\roaming\python\python310\site-packages (from torch->easyocr) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\thanu\appdata\roaming\python\python310\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: sympy in c:\users\thanu\appdata\roaming\python\python310\site-packages (from torch->easyocr) (1.13.3)
# Requirement already satisfied: networkx in c:\users\thanu\appdata\roaming\python\python310\site-packages (from torch->easyocr) (3.3)
# Requirement already satisfied: jinja2 in c:\users\thanu\appdata\roaming\python\python310\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\thanu\appdata\roaming\python\python310\site-packages (from torch->easyocr) (2024.9.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->easyocr)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr)
#   Downloading tifffile-2025.2.18-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in c:\users\thanu\appdata\roaming\python\python310\site-packages (from scikit-image->easyocr) (23.0)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\thanu\appdata\roaming\python\python310\site-packages (from jinja2->torch->easyocr) (2.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\thanu\appdata\roaming\python\python310\site-packages (from sympy->torch->easyocr) (1.3.0)
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 20.9 MB/s eta 0:00:00
# Downloading ninja-1.11.1.3-py3-none-win_amd64.whl (296 kB)
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    - -------------------------------------- 1.3/39.4 MB 11.2 MB/s eta 0:00:04
#    - -------------------------------------- 1.3/39.4 MB 11.2 MB/s eta 0:00:04
#    - -------------------------------------- 1.6/39.4 MB 2.7 MB/s eta 0:00:14
#    - -------------------------------------- 1.6/39.4 MB 2.7 MB/s eta 0:00:14
#    -- ------------------------------------- 2.1/39.4 MB 1.8 MB/s eta 0:00:21
#    -- ------------------------------------- 2.6/39.4 MB 2.0 MB/s eta 0:00:19
#    --- ------------------------------------ 3.9/39.4 MB 2.5 MB/s eta 0:00:15
#    ---- ----------------------------------- 4
9 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.3/12.8 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 8.7/12.8 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.8 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 4.6 MB/s eta 0:00:00
# Downloading shapely-2.0.7-cp310-cp310-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------------------------------ --- 1.3/1.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 6.3 MB/s eta 0:00:00
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2025.2.18-py3-none-any.whl (226 kB)
# Installing collected packages: python-bidi, pyclipper, tifffile, Shapely, opencv-python-headless, ninja, lazy-loader, imageio, scikit-image, easyocr
# Successfully installed Shapely-2.0.7 easyocr-1.7.2 imageio-2.37.0 lazy-loader-0.4 ninja-1.11.1.3 opencv-python-headless-4.11.0.86 pyclipper-1.3.0.post6 python-bidi-0.6.6 scikit-image-0.25.2 tifffile-2025.2.18
# WARNING: Ignoring invalid distribution -ip (c:\users\thanu\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\thanu\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\thanu\appdata\roaming\python\python310\site-packages)

# %%
from ultralytics import YOLO
import cv2
import easyocr

# %%
model = YOLO(r"C:\Users\thanu\runs\detect\train\weights\best.pt")

# %%
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |█-------------------------------------------------| 3.6% Complete
# Progress: |███-----------------------------------------------| 6.3% Complete
# Progress: |███-----------------------------------------------| 7.7% Complete
# Progress: |████----------------------------------------------| 9.1% Complete
# Progress: |█████---------------------------------------------| 10.4% Complete
# Progress: |█████---------------------------------------------| 11.7% Complete
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████----------------------------------------| 20.1% Complete
# Progress: |█████████████████---------------------------------| 34.3% Complete
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
image_path = r"C:\Users\thanu\code2024\Infosys Internship\Classification_model\aadhar.jpg"
results = model(image_path)
# Out:
# image 1/1 C:\Users\thanu\code2024\Infosys Internship\Classification_model\aadhar.jpg: 416x640 1 name, 1 uid, 152.5ms
# Speed: 6.6ms preprocess, 152.5ms inference, 4.5ms postprocess per image at shape (1, 3, 416, 640)

# %%
# Load the original image
image = cv2.imread(image_path)

# Dictionary to store extracted fields
extracted_data = {}

# %%
# Iterate through detections
for result in results[0].boxes.data.tolist():  # results[0].boxes.data contains bounding box details
    x1, y1, x2, y2, confidence, class_id = map(int, result[:6])
    field_class = model.names[class_id]  # Get class name (e.g., 'Name', 'UID', 'Address')

    # Crop the detected region
    cropped_roi = image[y1:y2, x1:x2]

    # Convert cropped ROI to grayscale for OCR
    gray_roi = cv2.cvtColor(cropped_roi, cv2.COLOR_BGR2GRAY)

    # Use EasyOCR to extract text
    text = reader.readtext(gray_roi, detail=0)  # detail=0 returns only the text

    # Save the text to the extracted_data dictionary
    extracted_data[field_class] = ' '.join(text)  # Combine detected text if multiple lines

# %%
# Print the extracted fields
print("Extracted Data:", extracted_data)
# Out:
# Extracted Data: {'uid': '8416 1590 3267', 'name': 'Sriram Mamundi'}
